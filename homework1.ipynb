# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import datetime as dt
import time

class one_news:
    '''Класс для хранения одной новости сайта. Имеет поля для заголовка, времени, тэгов, текста,
    которые все в таком порядке должны входить в конструктор.'''
    def __init__(self, title, date, tags, text):
        self.title = title
        self.date = date
        self.tags = tags
        self.text = text
    
class interview:
    '''Класс для хранения одного интервью. Имеет поля для заголовка, времени, тэгов, имени человека,
    аннотации, вопросов, ответов, которые все в таком порядке должны входить в конструктор.'''
    def __init__(self, title, date, tags, person, annotation, questions, answers):
        self.title = title
        self.date = date
        self.tags = tags
        self.person = person
        self.annotation = annotation
        self.questions = questions
        self.answers = answers
        
class f1news_scraper:
    '''Класс для парсера. Хранит в себе три массива: ссылки на новости, новости, интервью.
    Конструктор не принимает аргументов'''
    def __init__(self):
        self.news_links = []
        self.news = []
        self.interviews = []
        
    def get_all_for_period(self, date_start=dt.datetime.today().date(), date_end=dt.datetime.today().date()):
        '''Метод для сохранения новостей за период времени.
        Аргументами являются два объекта типа datetime: date_start, date_end.
        Период включает свои концы. По умолчанию, скачивает новости за текущий день.
        Данные сохраняются в поля объекта парсера.'''
        curr_date = date_end
        while(curr_date>=date_start):
            self.get_all_for_day(curr_date)
            curr_date = curr_date - dt.timedelta(days=1)
        del curr_date
    
    def get_all_for_day(self, date):
        '''Метод для скачивания новостей за определенный день. 
        В качестве аргумента получает объект типа datetime - date.
        Данные сохраняются в поля объекта парсера.
        '''
        links = self.get_new_links(date)
        for link in links:
            if '/interview' in link:
                try:
                    self.interviews.append(self.get_interview(link))
                except:
                    self.news.append(self.get_one_news(link))
            else:
                try:
                    self.news.append(self.get_one_news(link))
                except:
                    pass
            print('{0} is done'.format(link))
            time.sleep(2)
        del links
    
    def get_new_links(self, date) -> list:
        '''Метод для скачивания ссылок на новости за определенный день. 
        В качестве аргумента получает объект типа datetime - date.
        Возвращает список ссылок.
        '''
        new_links = []
        day_link = 'https://www.f1news.ru/news/{0}/{1}/{2}/'.format(date.year, date.month, date.day)
        page_text = BeautifulSoup(requests.get(day_link).text,"html5lib")
        divs = page_text.findAll('div', {'class':'article_title'})
        links = ["https://www.f1news.ru" + div.findAll('a')[0]['href'] for div in divs]
        for link in links:
            if not ('/archive/' in link) and not (link in self.news_links):
                self.news_links.append(link)
                new_links.append(link)
        del link, day_link, divs, page_text, links
        return new_links        
    
    def get_one_news(self, link) -> one_news:
        '''Скачивает новость по ссылке. Аргументом является link - строка с ссылкой на новость.
        Возвращает объект класса one_news'''
        page_text = BeautifulSoup(requests.get(link).text,"html5lib")
        news = one_news(page_text.find('h1').text, #title
                           dt.datetime.strptime(page_text.find('div', {'class':'post_date'})['content'], '%Y-%m-%dT%H:%M:%S%z'), #date
                           [a.text for a in page_text.find('ul', {'class':'tags'}).findAll('a')], #tags
                           [p.text.strip() for p in page_text.find('div', {'class':'post_content'}).findAll('p')], #text
                           )
        del page_text
        return news
    
    def get_interview(self, link) -> interview:
        '''Скачивает интервью по ссылке. Аргументом является link - строка с ссылкой на новость.
        Возвращает объект класса one_interview'''
        page_text = BeautifulSoup(requests.get(link).text,"html5lib")
        name = page_text.find('h1').text.split(':')[0]
        all_text = ' '.join([p.text.strip() for p in page_text.find('div', {'class':'post_content'}).findAll('p')][1:])
        all_text = all_text.split('Вопрос:')
        questions = []
        answers = []
        for part in all_text:
            if len(part)>0:
                splited = part.split('{0}:'.format(name))
                questions.append(splited[0].strip())
                answers.append(splited[1].strip())
        inter = interview(page_text.find('h1').text, #title
                           dt.datetime.strptime(page_text.find('div', {'class':'post_date'})['content'], '%Y-%m-%dT%H:%M:%S%z'), #date
                           [a.text for a in page_text.find('ul', {'class':'tags'}).findAll('a')], #tags
                           name, #person
                           page_text.find('div', {'class':'post_content'}).find('p').text, #annotation
                           questions, #questions
                           answers) #answers
        del page_text, name, all_text, questions, answers
        return inter
    
    def save_all(self, path):
        '''Сохраняет два файла (один с новостями, второй с интервью).
        Аргумент path - строка с путем до папки с файлами.'''
        self.save_interviews(path)
        self.save_news(path)
        
    def save_news(self, path):
        '''Сохраняет файл с новостями.
        Аргумент path - строка с путем до папки с файлом.'''
        df = pd.DataFrame(columns=['title', 'date', 'tags', 'text'])
        for one_n in self.news:
            df = df.append({'title':one_n.title, 'date':one_n.date, 'tags': one_n.tags, 'text': one_n.text},
                      ignore_index=True )
        df.to_csv(path+'news.csv', sep = ';')
        del df
    
    def save_interviews(self, path):
        '''Сохраняет файл с интервью.
        Аргумент path - строка с путем до папки с файлом.'''
        df = pd.DataFrame(columns=['title', 'date', 'tags', 'person', 'annotation', 'answers', 'questions'])
        for one_i in self.interviews:
            df = df.append({'title':one_i.title, 'date':one_i.date, 'tags': one_i.tags, 'person': one_i.person, 
                       'questions': one_i.questions, 'answers': one_i.answers}, ignore_index=True )
        df.to_csv(path+'interviews.csv', sep = ';')
        del df

scrap = f1news_scraper()
scrap.get_all_for_period(date_start = dt.datetime.today().date() - dt.timedelta(days=7)) #скачиваем новости за неделю
scrap.save_all('') #сохраняем новости в файл

news_df = pd.read_csv('news.csv', sep=';', index_col=0) #читаем и выводим на экран новсти из файлов
print(news_df.head())
inter_df = pd.read_csv('interviews.csv', sep=';', index_col=0)
print(inter_df.head())
# Out:
# https://www.f1news.ru/news/autosport-132464.html is done
# https://www.f1news.ru/news/f1-132463.html is done
# https://www.f1news.ru/news/f1-132462.html is done
# https://www.f1news.ru/news/f1-132461.html is done
# https://www.f1news.ru/news/f1-132460.html is done
# https://www.f1news.ru/news/f1-132459.html is done
# https://www.f1news.ru/news/f1-132458.html is done
# https://www.f1news.ru/news/autosport-132465.html is done
# https://www.f1news.ru/interview/hartley/132454.shtml is done
# https://www.f1news.ru/news/f1-132457.html is done
# https://www.f1news.ru/news/f1-132456.html is done
# https://www.f1news.ru/news/f1-132455.html is done
# https://www.f1news.ru/news/autosport-132453.html is done
# https://www.f1news.ru/news/f1-132452.html is done
# https://www.f1news.ru/news/f1-132451.html is done
# https://www.f1news.ru/news/f1-132450.html is done
# https://www.f1news.ru/interview/vandoorne/132449.shtml is done
# https://www.f1news.ru/news/f1-132448.html is done
# https://www.f1news.ru/news/f1-132445.html is done
# https://www.f1news.ru/news/f1-132443.html is done
# https://www.f1news.ru/news/f1-132371.html is done
# https://www.f1news.ru/news/f1-132447.html is done
# https://www.f1news.ru/interview/gasly/132446.shtml is done
# https://www.f1news.ru/interview/hamilton/132441.shtml is done
# https://www.f1news.ru/interview/wolff/132428.shtml is done
# https://www.f1news.ru/interview/alonso/132427.shtml is done
# https://www.f1news.ru/interview/horner/132426.shtml is done
# https://www.f1news.ru/news/f1-132294.html is done
# https://www.f1news.ru/Championship/2018/japan/press-sunday.shtml is done
# https://www.f1news.ru/interview/whiting/132444.shtml is done
# https://www.f1news.ru/interview/perez/132425.shtml is done
# https://www.f1news.ru/Championship/2018/japan/afterrace.shtml is done
# https://www.f1news.ru/news/f1-132442.html is done
# https://www.f1news.ru/news/f1-132440.html is done
# https://www.f1news.ru/news/f1-132439.html is done
# https://www.f1news.ru/news/f1-132438.html is done
# https://www.f1news.ruhttps://www.f1news.ru/gallery/v/2018/gp/japan/0710/ is done
# https://www.f1news.ru/news/f1-132436.html is done
# https://www.f1news.ru/news/f1-132435.html is done
# https://www.f1news.ru/news/f1-132434.html is done
# https://www.f1news.ru/news/f1-132433.html is done
# https://www.f1news.ru/news/f1-132432.html is done
# https://www.f1news.ru/news/f1-132431.html is done
# https://www.f1news.ru/news/f1-132430.html is done
# https://www.f1news.ru/news/f1-132429.html is done
# https://www.f1news.ru/Championship/2018/japan/tyres.shtml is done
# https://www.f1news.ru/news/f1-132423.html is done
# https://www.f1news.ru/news/f1-132424.html is done
# https://www.f1news.ru/news/f1-132422.html is done
# https://www.f1news.ru/interview/vettel/132421.shtml is done
# https://www.f1news.ru/news/f1-132420.html is done
# https://www.f1news.ru/news/f1-132419.html is done
# https://www.f1news.ru/news/f1-132418.html is done
# https://www.f1news.ru/news/f1-132417.html is done
# https://www.f1news.ru/news/f1-132416.html is done
# https://www.f1news.ru/Championship/2018/japan/race.shtml is done
# https://www.f1news.ru/news/f1-132412.html is done
# https://www.f1news.ru/news/f1-132413.html is done
# https://www.f1news.ru/news/f1-132411.html is done
# https://www.f1news.ru/news/f1-132408.html is done
# https://www.f1news.ru/news/f1-132410.html is done
# https://www.f1news.ru/news/f1-132409.html is done
# https://www.f1news.ru/news/f1-132407.html is done
# https://www.f1news.ru/news/f1-132406.html is done
# https://www.f1news.ru/news/f1-132405.html is done
# https://www.f1news.ru/news/f1-132404.html is done
# https://www.f1news.ru/interview/mhakkinen/132403.shtml is done
# https://www.f1news.ru/news/f1-132402.html is done
# https://www.f1news.ru/news/f1-132401.html is done
# https://www.f1news.ru/Championship/2018/japan/grid.shtml is done
# https://www.f1news.ru/news/f1-132372.html is done
# https://www.f1news.ru/interview/grosjean/132400.shtml is done
# https://www.f1news.ru/interview/vettel/132380.shtml is done
# https://www.f1news.ru/interview/tost/132383.shtml is done
# https://www.f1news.ru/interview/leclerc/132393.shtml is done
# https://www.f1news.ru/interview/gasly/132392.shtml is done
# https://www.f1news.ru/interview/ocon/132399.shtml is done
# https://www.f1news.ru/news/f1-132398.html is done
# https://www.f1news.ru/interview/wolff/132397.shtml is done
# https://www.f1news.ru/Championship/2018/japan/press-saturday.shtml is done
# https://www.f1news.ru/interview/raikkonen/132396.shtml is done
# https://www.f1news.ru/interview/sirotkin/132394.shtml is done
# https://www.f1news.ru/news/f1-132395.html is done
# https://www.f1news.ru/news/f1-132391.html is done
# https://www.f1news.ru/news/f1-132390.html is done
# https://www.f1news.ru/news/f1-132389.html is done
# https://www.f1news.ru/news/f1-132388.html is done
# https://www.f1news.ru/news/f1-132387.html is done
# https://www.f1news.ru/news/f1-132384.html is done
# https://www.f1news.ru/news/f1-132386.html is done
# https://www.f1news.ru/news/f1-132385.html is done
# https://www.f1news.ruhttps://www.f1news.ru/gallery/v/2018/gp/japan/0610/ is done
# https://www.f1news.ru/news/f1-132381.html is done
# https://www.f1news.ru/news/f1-132379.html is done
# https://www.f1news.ru/news/f1-132378.html is done
# https://www.f1news.ru/news/f1-132377.html is done
# https://www.f1news.ru/news/f1-132376.html is done
# https://www.f1news.ru/news/f1-132375.html is done
# https://www.f1news.ru/news/f1-132374.html is done
# https://www.f1news.ru/news/f1-132373.html is done
# https://www.f1news.ru/interview/vettel/132370.shtml is done
# https://www.f1news.ru/news/f1-132369.html is done
# https://www.f1news.ru/news/f1-132368.html is done
# https://www.f1news.ru/news/f1-132367.html is done
# https://www.f1news.ru/news/f1-132365.html is done
# https://www.f1news.ru/Championship/2018/japan/qual.shtml is done
# https://www.f1news.ru/news/f1-132363.html is done
# https://www.f1news.ru/news/f1-132362.html is done
# https://www.f1news.ru/news/f1-132361.html is done
# https://www.f1news.ru/news/f1-132360.html is done
# https://www.f1news.ru/news/f1-132359.html is done
# https://www.f1news.ru/Championship/2018/japan/saturday-free.shtml is done
# https://www.f1news.ru/interview/isola/132354.shtml is done
# https://www.f1news.ru/interview/vettel/132355.shtml is done
# https://www.f1news.ru/interview/raikkonen/132336.shtml is done
# https://www.f1news.ru/interview/stroll/132335.shtml is done
# https://www.f1news.ru/interview/szafnauer/132357.shtml is done
# https://www.f1news.ru/interview/magnussen/132340.shtml is done
# https://www.f1news.ru/Championship/2018/japan/press-friday.shtml is done
# https://www.f1news.ru/interview/ricciardo/132356.shtml is done
# https://www.f1news.ru/news/f1-132353.html is done
# https://www.f1news.ru/news/f1-132350.html is done
# https://www.f1news.ru/news/f1-132352.html is done
# https://www.f1news.ru/news/f1-132351.html is done
# https://www.f1news.ru/news/f1-132349.html is done
# https://www.f1news.ru/news/f1-132348.html is done
# https://www.f1news.ru/news/f1-132347.html is done
# https://www.f1news.ru/news/f1-132346.html is done
# https://www.f1news.ru/news/f1-132345.html is done
# https://www.f1news.ru/news/f1-132344.html is done
# https://www.f1news.ru/news/f1-132343.html is done
# https://www.f1news.ruhttps://www.f1news.ru/gallery/v/2018/gp/japan/0510/ is done
# https://www.f1news.ru/news/f1-132341.html is done
# https://www.f1news.ru/news/f1-132339.html is done
# https://www.f1news.ru/interview/grosjean/132338.shtml is done
# https://www.f1news.ru/news/f1-132337.html is done
# https://www.f1news.ru/interview/sirotkin/132333.shtml is done
# https://www.f1news.ru/news/f1-132334.html is done
# https://www.f1news.ru/interview/wolff/132332.shtml is done
# https://www.f1news.ru/news/f1-132331.html is done
# https://www.f1news.ru/news/f1-132330.html is done
# https://www.f1news.ru/news/f1-132315.html is done
# https://www.f1news.ru/Championship/2018/japan/friday-free.shtml is done
# https://www.f1news.ru/news/f1-132327.html is done
# https://www.f1news.ru/news/f1-132326.html is done
# https://www.f1news.ru/news/f1-132325.html is done
# https://www.f1news.ru/news/f1-132324.html is done
# https://www.f1news.ru/news/f1-132323.html is done
# https://www.f1news.ru/news/f1-132322.html is done
# https://www.f1news.ru/news/f1-132321.html is done
# https://www.f1news.ru/news/f1-132320.html is done
# https://www.f1news.ru/news/f1-132319.html is done
# https://www.f1news.ru/interview/gasly/132310.shtml is done
# https://www.f1news.ru/interview/alonso/132316.shtml is done
# https://www.f1news.ru/interview/bottas/132314.shtml is done
# https://www.f1news.ru/Championship/2018/japan/press-thursday.shtml is done
# https://www.f1news.ru/interview/max_verstappen/132313.shtml is done
# https://www.f1news.ru/interview/vettel/132311.shtml is done
# https://www.f1news.ruhttps://www.f1news.ru/gallery/v/2018/gp/japan/0410/ is done
# https://www.f1news.ru/news/f1-132309.html is done
# https://www.f1news.ru/interview/ricciardo/132308.shtml is done
# https://www.f1news.ru/news/f1-132307.html is done
# https://www.f1news.ru/interview/grosjean/132305.shtml is done
# https://www.f1news.ru/interview/sainz-junior/132306.shtml is done
# https://www.f1news.ru/news/f1-132304.html is done
# https://www.f1news.ru/news/f1-132303.html is done
# https://www.f1news.ru/interview/perez/132302.shtml is done
# https://www.f1news.ru/news/f1-132301.html is done
# https://www.f1news.ru/interview/sirotkin/132300.shtml is done
# https://www.f1news.ru/news/f1-132299.html is done
# https://www.f1news.ru/news/f1-132298.html is done
# https://www.f1news.ru/news/f1-132297.html is done
# https://www.f1news.ru/news/f1-132296.html is done
# https://www.f1news.ru/news/f1-132295.html is done
# https://www.f1news.ru/news/f1-132293.html is done
# https://www.f1news.ru/news/f1-132265.html is done
# https://www.f1news.ru/news/f1-132251.html is done
# https://www.f1news.ru/news/f1-132250.html is done
# https://www.f1news.ru/Championship/2018/japan/stats.shtml is done
# https://www.f1news.ru/Championship/2018/japan/preview.shtml is done
# https://www.f1news.ru/Championship/2018/japan/beforerace.shtml is done
# https://www.f1news.ru/Championship/2018/japan/index.shtml is done
# https://www.f1news.ru/news/f1-132266.html is done
# https://www.f1news.ru/interview/vasseur/132292.shtml is done
# https://www.f1news.ru/tech/132291.shtml is done
# https://www.f1news.ru/news/f1-132290.html is done
# https://www.f1news.ru/news/f1-132289.html is done
# https://www.f1news.ru/news/f1-132288.html is done
# https://www.f1news.ru/news/f1-132287.html is done
# https://www.f1news.ru/news/f1-132286.html is done
# https://www.f1news.ru/news/f1-132285.html is done
# https://www.f1news.ru/news/f1-132284.html is done
# https://www.f1news.ru/news/f1-132283.html is done
# https://www.f1news.ru/news/f1-132282.html is done
# https://www.f1news.ru/news/f1-132281.html is done
# https://www.f1news.ru/news/f1-132280.html is done
# https://www.f1news.ru/interview/titov/132258.shtml is done
# https://www.f1news.ru/news/f1-132279.html is done
# https://www.f1news.ru/news/f1-132278.html is done
# https://www.f1news.ru/interview/lowe/132277.shtml is done
# https://www.f1news.ru/news/f1-132276.html is done
# https://www.f1news.ru/news/f1-132275.html is done
# https://www.f1news.ru/interview/sainz-junior/132274.shtml is done
# https://www.f1news.ru/news/autosport-132273.html is done
# https://www.f1news.ru/interview/hulkenberg/132272.shtml is done
# https://www.f1news.ru/interview/chester/132271.shtml is done
# https://www.f1news.ru/news/f1-132270.html is done
# https://www.f1news.ru/news/f1-132269.html is done
# https://www.f1news.ru/tech/132268.shtml is done
# https://www.f1news.ru/news/f1-132267.html is done
# https://www.f1news.ru/news/f1-132264.html is done
# https://www.f1news.ru/news/f1-132263.html is done
# https://www.f1news.ru/news/f1-132262.html is done
# https://www.f1news.ru/interview/magnussen/132261.shtml is done
# https://www.f1news.ru/interview/grosjean/132260.shtml is done
# https://www.f1news.ru/interview/steiner/132259.shtml is done
# https://www.f1news.ru/interview/leclerc/132257.shtml is done
#                                               title  \
# 0         Формула Е: Представлена трасса в Сантьяго
# 1        Йос Ферстаппен недоволен решением стюардов
# 2              Итальянская пресса: Ferrari в руинах
# 3    В Сузуке завершился первый день тестов Pirelli
# 4  Хэмилтон хочет, чтобы Ferrari вернулась в борьбу
#
#                         date  \
# 0  2018-10-09 14:54:00+03:00
# 1  2018-10-09 14:39:00+03:00
# 2  2018-10-09 14:11:00+03:00
# 3  2018-10-09 13:19:00+03:00
# 4  2018-10-09 13:10:00+03:00
#
#                                                 tags  \
# 0                                      ['Формула Е']
# 1  ['Йос Ферстаппен', 'Макс Ферстаппен', 'Red Bul...
# 2                   ['Себастьян Феттель', 'Ferrari']
# 3                         ['Джек Эйткен', 'Renault']
# 4          ['Льюис Хэмилтон', 'Ferrari', 'Mercedes']
#
#                                                 text
# 0  ['Организаторы Формулы Е представили эскиз гор...
# 1  ['Стюарды Гран При Японии наказали Макса Ферст...
# 2  ['После Гран При Японии у Себастьяна Феттеля е...
# 3  ['В Японии завершился первый из двух дней очер...
# 4  ['Льюис Хэмилтон уверенно выиграл Гран При Япо...
#                                                title  \
# 0  Брендон Хартли: Судьбу гонки решили проблемы с...
# 1  Вандорн: Постараюсь поддерживать связь с Форму...
# 2       Пьер Гасли: Я не хочу никого обвинять, но...
# 3           Хэмилтон: Я чувствую себя очень уверенно
# 4   Тото Вольфф: Для нас это была настоящая проверка
#
#                         date                              tags  \
# 0  2018-10-08 21:10:00+03:00  ['Брендон Хартли', 'Toro Rosso']
# 1  2018-10-08 13:51:00+03:00   ['Стоффель Вандорн', 'McLaren']
# 2  2018-10-07 20:28:00+03:00      ['Пьер Гасли', 'Toro Rosso']
# 3  2018-10-07 19:15:00+03:00    ['Льюис Хэмилтон', 'Mercedes']
# 4  2018-10-07 18:05:00+03:00       ['Тото Вольфф', 'Mercedes']
#
#            person  annotation  \
# 0  Брендон Хартли         NaN
# 1         Вандорн         NaN
# 2      Пьер Гасли         NaN
# 3        Хэмилтон         NaN
# 4     Тото Вольфф         NaN
#
#                                              answers  \
# 0  ['Команда расстроена итогами гонки. Мы с Пьеро...
# 1  ['Для нас гонка получилась долгой. В начале пр...
# 2  ['Как я сказал вчера, в квалификации возникли ...
# 3  ['Потрясающе находиться в Японии, здесь фантас...
# 4  ['Да, отличный уик-энд, мы хорошо его начали, ...
#
#                                            questions
# 0  ['Брендон, как вы оцениваете результат?', 'Пос...
# 1  ['В Японии вы стартовали 19-м и финишировали 1...
# 2  ['На стартовой решетке вы говорили о каких-то ...
# 3  ['Льюис, превосходное выступление! Если в Ости...
# 4  ['Это был ещё один впечатляющий уик-энд в испо...
